# %% [markdown]
# ## LightGBM performs slightly better than Random Forest (AVG score: 0.533 vs 0.523), but it is much faster than Random Forest (30min vs 1h16min).

# %% [markdown]
# The feature selection notebook does a filter followed by a wrapper. It's capable of doing the filter on more than one file. The variable files are called vars1.csv, vars2.csv ...
#
# The filter runs separately on each vars file and keeps the top num_filter variables from each file. If there are more than one vars files we'll again select the top num_filter variables across all the vars.csv files.
#
# If balance = 0 the entire files are used. If balance != 0 then balance is the ratio of goods to bads retained for the rest of the feature selection. We keep all the rare class (bads) and downsample the goods.
#
# BUT RIGHT NOW I'VE GOT A BUG SOMEWHERE: balance !=0 doesn't work when num_files > 1. I've got an index problem.
#
# So you can run with multiple variables files only when balance=0, or you can run with only one variable file and set balance how you like.

# %%
# load libraries
# %pip install mlxtend

import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import datetime as dt
import gc
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
# %matplotlib inline
start_time = dt.datetime.now()

# %%
# set some parameters
num_files = 3
num_filter = 100
num_wrapper = 30
# keep balance = 0 when num_files > 1 until I figure out this bug. Maybe somebody else can figure it out.
balance = 0
detect_rate = .03
index_name = 'record'
y_name = 'fraud_label'
good_label = 0
bad_label = 1

# %% [markdown]
# ## Run a filter on all the files

# %%
# %%time
for i in range(num_files):
    file_name = "vars"+str(i+1)+'.csv'
    df = pd.read_csv(file_name)
    print('work on file ', file_name)
    df = df[df[index_name] <= 833508] # remove the last two months as the out-of-time data (OOT)
    df = df[df[index_name] >= 38512] # remove the first 2 weeks of records since their variables aren't well formed
    df['RANDOM'] = np.random.ranf(len(df)) # add a random number variable to make sure it doesn't come up as important
    goods = df[df[y_name] == good_label]
    bads = df[df[y_name] == bad_label]
    del df # don't need this file anymore
    num_goods = len(goods)
    num_bads = len(bads)
    num_vars = len(bads.columns)-2
    if(balance != 0):
        if(i == 0):
            num_goods_desired = int(min(num_goods,num_bads*balance))
            goods = goods.sample(n=num_goods_desired,random_state=1)
            goods_keep = list(goods.index)
            goods_keep.sort()
    
        if(i > 0):
            goods.set_index(index_name, inplace=True)
            goods.sort_index(inplace=True)
            goods = goods.iloc[goods_keep] # THERE'S SOMETHING WRONG HERE AND I CAN'T FIGURE IT OUT
            
    df_sampled = pd.concat([goods,bads])
    df_sampled.set_index(index_name, inplace=True)
    df_sampled.sort_index(inplace=True)
    if(i == 0): # if first time through need to initialize some stuff
        Y = pd.DataFrame(df_sampled[y_name], index=df_sampled.index)
        filter_score = pd.DataFrame(np.zeros((num_vars+1,2)))
        filter_score.columns = ['variable','score']   
        j = 0
        for column in df_sampled:
            filter_score.loc[j,'variable'] = column
            filter_score.loc[j,'score'] = sps.ks_2samp(goods[column],bads[column])[0]
            j = j+1
            
        filter_score.sort_values(by=['score'], ascending=False, inplace=True)
        vars_keep = list(filter_score['variable'][1:num_filter+1])
        print(filter_score.head(num_filter))
        df_top = df_sampled.filter(vars_keep, axis=1)
            
    if(i > 0): # if more than one variable file we use this loop
        new = pd.DataFrame(np.zeros((num_vars+1,2)))
        new.columns = ['variable','score']   
        j = 0
        for column in df_sampled:
            new.loc[j,'variable'] = column
            new.loc[j,'score'] = sps.ks_2samp(goods[column],bads[column])[0]
            j = j+1
        
        new.sort_values(by=['score'], ascending=False, inplace=True)
        vars_keep = list(new['variable'][1:num_filter+1])
        print(new.head(num_filter))
        data_new_top = df_sampled.filter(vars_keep, axis=1)
        df_top = pd.concat([df_top,data_new_top], axis=1)
        filter_score = pd.concat([filter_score,new])
    
    del goods # delete these before starting the next file, if any
    del bads
    gc.collect()
# Out:
# work on file  vars1.csv
#                           variable     score
# 9                      fraud_label  1.000000
# 42               address_day_since  0.334096
# 70           fulladdress_day_since  0.333210
# 48                address_count_30  0.332725
# 76            fulladdress_count_30  0.332032
# ..                             ...       ...
# 201      ssn_name_app_age_count_14  0.201184
# 109  fulladdress_homephone_count_7  0.199751
# 59               homephone_count_3  0.194923
# 253         name_dob_count_0_by_14  0.194791
# 60               homephone_count_7  0.194198
#
# [100 rows x 2 columns]
# work on file  vars2.csv
#                                              variable     score
# 501                                       fraud_label  1.000000
# 38   fulladdress_unique_count_for_ssn_name_app_age_30  0.314401
# 39   fulladdress_unique_count_for_ssn_name_app_age_60  0.311215
# 37   fulladdress_unique_count_for_ssn_name_app_age_14  0.287815
# 21           fulladdress_unique_count_for_ssn_name_60  0.286665
# ..                                                ...       ...
# 360     ssn_lastname_unique_count_for_dob_homephone_7  0.163498
# 83               name_dob_unique_count_for_ssn_zip3_3  0.158177
# 77               name_dob_unique_count_for_ssn_zip5_3  0.158177
# 95        name_dob_unique_count_for_ssn_fulladdress_3  0.158171
# 65          name_dob_unique_count_for_dob_homephone_3  0.157968
#
# [100 rows x 2 columns]
# work on file  vars3.csv
#                                               variable     score
# 332                                        fraud_label  1.000000
# 235          ssn_name_dob_unique_count_for_ssn_zip5_60  0.179292
# 91               ssn_name_unique_count_for_ssn_zip5_60  0.179215
# 241          ssn_name_dob_unique_count_for_ssn_zip3_60  0.179205
# 199       ssn_name_dob_unique_count_for_fulladdress_60  0.179195
# ..                                                 ...       ...
# 87                ssn_name_unique_count_for_ssn_zip5_3  0.157241
# 63        ssn_name_unique_count_for_name_fulladdress_3  0.157231
# 99         ssn_name_unique_count_for_ssn_fulladdress_3  0.157231
# 51             ssn_name_unique_count_for_fulladdress_3  0.157231
# 285  ssn_name_app_age_unique_count_for_fulladdress_...  0.155665
#
# [100 rows x 2 columns]
# CPU times: user 4min 36s, sys: 1min 6s, total: 5min 42s
# Wall time: 5min 58s

# %%
filter_score.sort_values(by=['score'], ascending=False, inplace=True)

# %%
filter_score.head(33)
# Out:
#                                              variable     score
# 9                                         fraud_label  1.000000
# 332                                       fraud_label  1.000000
# 501                                       fraud_label  1.000000
# 42                                  address_day_since  0.334096
# 70                              fulladdress_day_since  0.333210
# 48                                   address_count_30  0.332725
# 76                               fulladdress_count_30  0.332032
# 47                                   address_count_14  0.322252
# 75                               fulladdress_count_14  0.321756
# 38   fulladdress_unique_count_for_ssn_name_app_age_30  0.314401
# 39   fulladdress_unique_count_for_ssn_name_app_age_60  0.311215
# 46                                    address_count_7  0.301445
# 74                                fulladdress_count_7  0.301368
# 214                             address_count_0_by_30  0.291997
# 246                         fulladdress_count_0_by_30  0.290783
# 496     fulladdress_unique_count_for_dob_homephone_60  0.288325
# 37   fulladdress_unique_count_for_ssn_name_app_age_14  0.287815
# 21           fulladdress_unique_count_for_ssn_name_60  0.286665
# 3        fulladdress_unique_count_for_ssn_lastname_60  0.286641
# 472               fulladdress_unique_count_for_ssn_60  0.286630
# 9            fulladdress_unique_count_for_ssn_zip5_60  0.286630
# 15           fulladdress_unique_count_for_ssn_zip3_60  0.286630
# 27    fulladdress_unique_count_for_ssn_fulladdress_60  0.286630
# 33       fulladdress_unique_count_for_ssn_name_dob_60  0.284611
# 484  fulladdress_unique_count_for_name_fulladdress_60  0.284394
# 478          fulladdress_unique_count_for_name_dob_60  0.282877
# 490   fulladdress_unique_count_for_fulladdress_dob_60  0.282847
# 495     fulladdress_unique_count_for_dob_homephone_30  0.282845
# 20           fulladdress_unique_count_for_ssn_name_30  0.281881
# 2        fulladdress_unique_count_for_ssn_lastname_30  0.281829
# 8            fulladdress_unique_count_for_ssn_zip5_30  0.281795
# 14           fulladdress_unique_count_for_ssn_zip3_30  0.281795
# 471               fulladdress_unique_count_for_ssn_30  0.281795

# %%
filter_score.tail(10)
# Out:
#                                               variable  score
# 44                     ssn_name_unique_count_for_ssn_1    0.0
# 301  ssn_name_app_age_unique_count_for_ssn_lastname_60    0.0
# 193    fulladdress_dob_unique_count_for_fulladdress_14    0.0
# 400                    ssn_zip5_unique_count_for_ssn_1    0.0
# 401                    ssn_zip5_unique_count_for_ssn_3    0.0
# 402                    ssn_zip5_unique_count_for_ssn_7    0.0
# 477                   ssn_zip3_unique_count_for_ssn_60    0.0
# 476                   ssn_zip3_unique_count_for_ssn_30    0.0
# 475                   ssn_zip3_unique_count_for_ssn_14    0.0
# 167       ssn_fulladdress_unique_count_for_ssn_zip3_14    0.0

# %%
filter_score.shape
# Out:
# (1338, 2)

# %%
filter_score.sort_values(by=['score'], ascending=False, inplace=True)
vars_keep = list(filter_score['variable'][num_files:num_filter+3])
print(i,' vars_keep:',vars_keep)
# Out:
# 2  vars_keep: ['address_day_since', 'fulladdress_day_since', 'address_count_30', 'fulladdress_count_30', 'address_count_14', 'fulladdress_count_14', 'fulladdress_unique_count_for_ssn_name_app_age_30', 'fulladdress_unique_count_for_ssn_name_app_age_60', 'address_count_7', 'fulladdress_count_7', 'address_count_0_by_30', 'fulladdress_count_0_by_30', 'fulladdress_unique_count_for_dob_homephone_60', 'fulladdress_unique_count_for_ssn_name_app_age_14', 'fulladdress_unique_count_for_ssn_name_60', 'fulladdress_unique_count_for_ssn_lastname_60', 'fulladdress_unique_count_for_ssn_60', 'fulladdress_unique_count_for_ssn_zip5_60', 'fulladdress_unique_count_for_ssn_zip3_60', 'fulladdress_unique_count_for_ssn_fulladdress_60', 'fulladdress_unique_count_for_ssn_name_dob_60', 'fulladdress_unique_count_for_name_fulladdress_60', 'fulladdress_unique_count_for_name_dob_60', 'fulladdress_unique_count_for_fulladdress_dob_60', 'fulladdress_unique_count_for_dob_homephone_30', 'fulladdress_unique_count_for_ssn_name_30', 'fulladdress_unique_count_for_ssn_lastname_30', 'fulladdress_unique_count_for_ssn_zip5_30', 'fulladdress_unique_count_for_ssn_zip3_30', 'fulladdress_unique_count_for_ssn_30', 'fulladdress_unique_count_for_ssn_fulladdress_30', 'address_count_0_by_14', 'fulladdress_unique_count_for_ssn_name_dob_30', 'fulladdress_count_0_by_14', 'fulladdress_unique_count_for_name_fulladdress_30', 'fulladdress_unique_count_for_name_dob_30', 'fulladdress_unique_count_for_fulladdress_dob_30', 'fulladdress_count_3', 'address_count_3', 'fulladdress_unique_count_for_dob_homephone_14', 'fulladdress_unique_count_for_ssn_name_app_age_7', 'fulladdress_unique_count_for_ssn_name_14', 'fulladdress_unique_count_for_ssn_lastname_14', 'fulladdress_unique_count_for_ssn_zip3_14', 'fulladdress_unique_count_for_ssn_fulladdress_14', 'fulladdress_unique_count_for_ssn_14', 'fulladdress_unique_count_for_ssn_zip5_14', 'fulladdress_unique_count_for_ssn_name_dob_14', 'fulladdress_unique_count_for_name_fulladdress_14', 'fulladdress_unique_count_for_name_dob_14', 'fulladdress_unique_count_for_fulladdress_dob_14', 'fulladdress_unique_count_for_dob_homephone_7', 'fulladdress_unique_count_for_ssn_zip5_7', 'fulladdress_unique_count_for_ssn_fulladdress_7', 'fulladdress_unique_count_for_ssn_7', 'fulladdress_unique_count_for_ssn_zip3_7', 'fulladdress_unique_count_for_ssn_lastname_7', 'fulladdress_unique_count_for_ssn_name_7', 'fulladdress_unique_count_for_ssn_name_dob_7', 'fulladdress_unique_count_for_name_fulladdress_7', 'fulladdress_unique_count_for_fulladdress_dob_7', 'fulladdress_unique_count_for_name_dob_7', 'fulladdress_unique_count_for_ssn_name_app_age_3', 'fulladdress_unique_count_for_dob_homephone_3', 'fulladdress_unique_count_for_ssn_name_dob_3', 'fulladdress_unique_count_for_ssn_zip5_3', 'fulladdress_unique_count_for_ssn_fulladdress_3', 'fulladdress_unique_count_for_ssn_zip3_3', 'fulladdress_unique_count_for_ssn_3', 'fulladdress_unique_count_for_ssn_lastname_3', 'fulladdress_unique_count_for_ssn_name_3', 'fulladdress_unique_count_for_fulladdress_dob_3', 'fulladdress_unique_count_for_name_dob_3', 'fulladdress_unique_count_for_name_fulladdress_3', 'address_count_0_by_7', 'fulladdress_count_0_by_7', 'address_count_1', 'fulladdress_count_1', 'fulladdress_unique_count_for_dob_homephone_1', 'fulladdress_unique_count_for_ssn_name_app_age_1', 'fulladdress_unique_count_for_ssn_name_dob_1', 'fulladdress_unique_count_for_fulladdress_dob_1', 'fulladdress_unique_count_for_name_dob_1', 'fulladdress_unique_count_for_ssn_fulladdress_1', 'fulladdress_unique_count_for_ssn_zip5_1', 'fulladdress_unique_count_for_ssn_zip3_1', 'fulladdress_unique_count_for_ssn_1', 'fulladdress_unique_count_for_ssn_lastname_1', 'fulladdress_unique_count_for_ssn_name_1', 'fulladdress_unique_count_for_name_fulladdress_1', 'fulladdress_count_0_by_3', 'address_count_0_by_3', 'fulladdress_homephone_day_since', 'fulladdress_homephone_count_30', 'ssn_dob_day_since', 'ssn_dob_count_30', 'name_dob_day_since', 'name_dob_count_30',  ...

# %%
df_keep = df_top.filter(vars_keep, axis=1)
df_keep.head()
# Out:
#         address_day_since  fulladdress_day_since  address_count_30  \
# record
# 38512               365.0                  365.0                 1
# 38513               365.0                  365.0                 1
# 38514               365.0                  365.0                 1
# 38515               365.0                  365.0                 1
# 38516               365.0                  365.0                 1
#
#         fulladdress_count_30  address_count_14  fulladdress_count_14  \
# record
# 38512                      1                 1                     1
# 38513                      1                 1                     1
# 38514                      1                 1                     1
# 38515                      1                 1                     1
# 38516                      1                 1                     1
#
#         fulladdress_unique_count_for_ssn_name_app_age_30  \
# record
# 38512                                                  1
# 38513                                                  1
# 38514                                                  1
# 38515                                                  1
# 38516                                                  1
#
#         fulladdress_unique_count_for_ssn_name_app_age_60  address_count_7  \
# record
# 38512                                                  1                1
# 38513                                                  1                1
# 38514                                                  1                1
# 38515                                                  1                1
# 38516                                                  1                1
#
#         fulladdress_count_7  ...  fulladdress_count_0_by_3  \
# record                       ...
# 38512                     1  ...                       3.0
# 38513                     1  ...                       3.0
# 38514                     1  ...                       3.0
# 38515                     1  ...                       3.0
# 38516                     1  ...                       3.0
#
#         address_count_0_by_3  fulladdress_homephone_day_since  \
# record
# 38512                    3.0                            365.0
# 38513                    3.0                            365.0
# 38514                    3.0                            365.0
# 38515                    3.0                            365.0
# 38516                    3.0                            365.0
#
#         fulladdress_homephone_count_30  ssn_dob_day_since  ssn_dob_count_30  \
# record
# 38512                                1              365.0                 1
# 38513                                1              365.0                 1
# 38514                                1              365.0                 1
# 38515                                1              365.0                 1
# 38516                                1              365.0                 1
#
#         name_dob_day_since  name_dob_count_30  ssn_day_since  ssn_count_30
# record
# 38512                365.0                  1          365.0             1
# 38513                365.0                  1          365.0             1
# 38514                365.0                  1          365.0             1
# 38515                365.0                  1          365.0             1
# 38516                365.0                  1          365.0             1
#
# [5 rows x 100 columns]

# %%
df_keep = df_top.filter(vars_keep, axis=1)
df_keep.head()
# Out:
#         address_day_since  fulladdress_day_since  address_count_30  \
# record
# 38512               365.0                  365.0                 1
# 38513               365.0                  365.0                 1
# 38514               365.0                  365.0                 1
# 38515               365.0                  365.0                 1
# 38516               365.0                  365.0                 1
#
#         fulladdress_count_30  address_count_14  fulladdress_count_14  \
# record
# 38512                      1                 1                     1
# 38513                      1                 1                     1
# 38514                      1                 1                     1
# 38515                      1                 1                     1
# 38516                      1                 1                     1
#
#         fulladdress_unique_count_for_ssn_name_app_age_30  \
# record
# 38512                                                  1
# 38513                                                  1
# 38514                                                  1
# 38515                                                  1
# 38516                                                  1
#
#         fulladdress_unique_count_for_ssn_name_app_age_60  address_count_7  \
# record
# 38512                                                  1                1
# 38513                                                  1                1
# 38514                                                  1                1
# 38515                                                  1                1
# 38516                                                  1                1
#
#         fulladdress_count_7  ...  fulladdress_count_0_by_3  \
# record                       ...
# 38512                     1  ...                       3.0
# 38513                     1  ...                       3.0
# 38514                     1  ...                       3.0
# 38515                     1  ...                       3.0
# 38516                     1  ...                       3.0
#
#         address_count_0_by_3  fulladdress_homephone_day_since  \
# record
# 38512                    3.0                            365.0
# 38513                    3.0                            365.0
# 38514                    3.0                            365.0
# 38515                    3.0                            365.0
# 38516                    3.0                            365.0
#
#         fulladdress_homephone_count_30  ssn_dob_day_since  ssn_dob_count_30  \
# record
# 38512                                1              365.0                 1
# 38513                                1              365.0                 1
# 38514                                1              365.0                 1
# 38515                                1              365.0                 1
# 38516                                1              365.0                 1
#
#         name_dob_day_since  name_dob_count_30  ssn_day_since  ssn_count_30
# record
# 38512                365.0                  1          365.0             1
# 38513                365.0                  1          365.0             1
# 38514                365.0                  1          365.0             1
# 38515                365.0                  1          365.0             1
# 38516                365.0                  1          365.0             1
#
# [5 rows x 100 columns]

# %%
df_keep.shape
# Out:
# (794997, 100)

# %%
Y.head()
# Out:
#         fraud_label
# record
# 38512             0
# 38513             0
# 38514             0
# 38515             0
# 38516             0

# %%
Y = Y.values
X = df_keep

# %%
print('time to here:', dt.datetime.now() - start_time)
# Out:
# time to here: 0:06:07.985626

# %%
print(X.shape,Y.shape)
# Out:
# (794997, 100) (794997, 1)

# %%
# I'd like to define a scoring for the wrapper that's KS, but I haven't gotten around to this yet.
# def KSscore(classifier, x,y)
#     goods =

# %%
def fdr(classifier, x, y, cutoff=detect_rate):
# Calculates FDR score for the given classifier on dataset x and y with cutoff value
# get the probability list from the given classifier
    return fdr_prob(y, classifier.predict_proba(x), cutoff)
def fdr_prob(y, y_prob, cutoff=detect_rate):
    if len(y_prob.shape) != 1:    # sometimes the proba list can contain many columns, one for each category
        y_prob = y_prob[:, -1:]   # only the last one (fraud_label==1) is used here.
    num_fraud = len(y[y == 1])    # count the total nunber of frauds   
# sort the proba list from high to low while retain the true (not predicted) fraud label
    sorted_prob = np.asarray(sorted(zip(y_prob, y), key=lambda x: x[0], reverse=True))
    cutoff_bin = sorted_prob[0:int(len(y) * cutoff), 1:]  # 3% cutoff
# return the FDR score (#fraud_in_cutoff / #total_fraud)
    return len(cutoff_bin[cutoff_bin == 1]) / num_fraud

# %%
# %%time
# If you're doing forward selection it's enough to stop at num_wrapper variables. 
# If you're doing backward selection you need to go through all the variables to get 
# a sorted list of num_wrapper variables.
nfeatures = len(X.columns)
clf = LGBMClassifier(n_estimators=5, n_jobs=-1) # simple, fast nonlinear model for the wrapper
sfs = SFS(clf,k_features=num_wrapper,forward=True,verbose=2,scoring=fdr,cv=2,n_jobs=-1) # forward selection
# sfs = SFS(clf,k_features=1,forward=False,verbose=2,scoring=fdr,cv=2,n_jobs=-1) # backward selection
sfs.fit(X,Y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   44.9s finished
#
# [2022-02-27 18:39:39] Features: 1/30 -- score: 0.35425735678216963[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  99 out of  99 | elapsed:   49.3s finished
#
# [2022-02-27 18:40:29] Features: 2/30 -- score: 0.5155841894480238[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:   51.2s finished
#
# [2022-02-27 18:41:20] Features: 3/30 -- score: 0.5220268152533519[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done  97 out of  97 | elapsed:   52.4s finished
#
# [2022-02-27 18:42:13] Features: 4/30 -- score: 0.524812815601602[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:   52.1s finished
#
# [2022-02-27 18:43:05] Features: 5/30 -- score: 0.5248998781124847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done  95 out of  95 | elapsed:   52.2s finished
#
# [2022-02-27 18:43:57] Features: 6/30 -- score: 0.5248998781124847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done  94 out of  94 | elapsed:   52.9s finished
#
# [2022-02-27 18:44:50] Features: 7/30 -- score: 0.524812815601602[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done  93 out of  93 | elapsed:   52.8s finished
#
# [2022-02-27 18:45:43] Features: 8/30 -- score: 0.5248998781124847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done  92 out of  92 | elapsed:   54.0s finished
#
# [2022-02-27 18:46:38] Features: 9/30 -- score: 0.524812815601602[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done  91 out of  91 | elapsed:   54.1s finished
#
# [2022-02-27 18:47:32] Features: 10/30 -- score: 0.524812815601602[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:   54.6s finished
#
# [2022-02-27 18:48:27] Features: 11/30 -- score: 0.524812815601602[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done  89 out of  89 | elapsed:   55.5s finished
#
# [2022-02-27 18:49:23] Features: 12/30 -- score: 0.5242904405363051[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:  1.0min finished
#
# [2022-02-27 18:50:26] Features: 13/30 -- score: 0.5298624412328052[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done  87 out of  87 | elapsed:  1.1min finished
#
# [2022-02-27 18:51:31] Features: 14/30 -- score: 0.531342503917813[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done  86 out of  86 | elapsed:  1.1min finished
#
# [2022-02-27 18:52:36] Features: 15/30 -- score: 0.5330837541354693[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done  85 out of  85 | elapsed:  1.1min finished
#
# [2022-02-27 18:53:42] Features: 16/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:  1.2min finished
#
# [2022-02-27 18:54:53] Features: 17/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done  83 out of  83 | elapsed:  1.2min finished
#
# [2022-02-27 18:56:03] Features: 18/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done  82 out of  82 | elapsed:  1.2min finished
#
# [2022-02-27 18:57:15] Features: 19/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:  1.2min finished
#
# [2022-02-27 18:58:28] Features: 20/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  1.2min finished
#
# [2022-02-27 18:59:41] Features: 21/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done  79 out of  79 | elapsed:  1.2min finished
#
# [2022-02-27 19:00:52] Features: 22/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done  78 out of  78 | elapsed:  1.2min finished
#
# [2022-02-27 19:02:05] Features: 23/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done  77 out of  77 | elapsed:  1.6min finished
#
# [2022-02-27 19:03:45] Features: 24/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:  1.3min finished
#
# [2022-02-27 19:05:03] Features: 25/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:  1.3min finished
#
# [2022-02-27 19:06:19] Features: 26/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done  74 out of  74 | elapsed:  1.2min finished
#
# [2022-02-27 19:07:34] Features: 27/30 -- score: 0.5332578791572349[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done  73 out of  73 | elapsed:  1.2min finished
#
# [2022-02-27 19:08:50] Features: 28/30 -- score: 0.5331708166463521[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:  1.2min finished
#
# [2022-02-27 19:10:05] Features: 29/30 -- score: 0.5331708166463521[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done  71 out of  71 | elapsed:  1.2min finished
# CPU times: user 3min 36s, sys: 9min 38s, total: 13min 15s
# Wall time: 32min 27s
# [2022-02-27 19:11:20] Features: 30/30 -- score: 0.5331708166463521
# SequentialFeatureSelector(cv=2, estimator=LGBMClassifier(n_estimators=5),
#                           k_features=30, n_jobs=-1,
#                           scoring=<function fdr at 0x7f8dfb0443a0>, verbose=2)

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
fig1 = plot_sfs(sfs.get_metric_dict(),kind='std_dev', figsize=(15, 6))
plt.xticks(np.arange(0, len(X.columns), step=5))
plt.ylim([0., .7])
plt.xlim(0,num_wrapper)
plt.title('Stepwise Selection')
plt.grid()
plt.savefig('FS_fdr.png')
plt.show()

# %%
vars_FS = pd.DataFrame.from_dict(sfs.get_metric_dict()).T
vars_FS
# Out:
#                                           feature_idx  \
# 1                                                (3,)
# 2                                             (3, 95)
# 3                                         (3, 12, 95)
# 4                                      (2, 3, 12, 95)
# 5                                  (2, 3, 12, 20, 95)
# 6                              (2, 3, 12, 20, 22, 95)
# 7                          (2, 3, 12, 20, 22, 95, 97)
# 8                      (2, 3, 12, 20, 22, 32, 95, 97)
# 9                  (2, 3, 12, 20, 22, 24, 32, 95, 97)
# 10             (2, 3, 12, 20, 22, 24, 32, 35, 95, 97)
# 11         (2, 3, 12, 20, 22, 24, 32, 35, 36, 95, 97)
# 12      (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 95, 97)
# 13  (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 92, 95, 97)
# 14  (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 92, 94, ...
# 15  (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 47, 92, ...
# 16  (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 47, 92, ...
# 17  (0, 2, 3, 4, 12, 20, 22, 24, 32, 35, 36, 47, 9...
# 18  (0, 1, 2, 3, 4, 12, 20, 22, 24, 32, 35, 36, 47...
# 19  (0, 1, 2, 3, 4, 5, 12, 20, 22, 24, 32, 35, 36,...
# 20  (0, 1, 2, 3, 4, 5, 8, 12, 20, 22, 24, 32, 35, ...
# 21  (0, 1, 2, 3, 4, 5, 8, 9, 12, 20, 22, 24, 32, 3...
# 22  (0, 1, 2, 3, 4, 5, 8, 9, 12, 20, 22, 24, 32, 3...
# 23  (0, 1, 2, 3, 4, 5, 8, 9, 10, 12, 20, 22, 24, 3...
# 24  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 25  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 26  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 27  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 28  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 29  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 30  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
#
#                                    cv_scores avg_score  \
# 1    [0.351732543966568, 0.3567821695977712]  0.354257
# 2    [0.5035695629461954, 0.527598815949852]  0.515584
# 3   [0.5072261884032736, 0.5368274421034303]  0.522027
# 4   [0.5075744384468048, 0.5420511927563991]  0.524813
# 5   [0.5077485634685704, 0.5420511927563991]    0.5249
# 6   [0.5077485634685704, 0.5420511927563991]    0.5249
# 7   [0.5075744384468048, 0.5420511927563991]  0.524813
# 8   [0.5077485634685704, 0.5420511927563991]    0.5249
# 9   [0.5075744384468048, 0.5420511927563991]  0.524813
# 10  [0.5075744384468048, 0.5420511927563991]  0.524813
# 11  [0.5075744384468048, 0.5420511927563991]  0.524813
# 12  [0.5077485634685704, 0.5408323176040397]   0.52429
# 13  [0.5121016890127111, 0.5476231934528992]  0.529862
# 14  [0.5143653142956642, 0.5483196935399617]  0.531343
# 15  [0.5143653142956642, 0.5518021939752743]  0.533084
# 16  [0.5147135643391956, 0.5518021939752743]  0.533258
# 17  [0.5147135643391956, 0.5518021939752743]  0.533258
# 18  [0.5147135643391956, 0.5518021939752743]  0.533258
# 19  [0.5147135643391956, 0.5518021939752743]  0.533258
# 20  [0.5147135643391956, 0.5518021939752743]  0.533258
# 21  [0.5147135643391956, 0.5518021939752743]  0.533258
# 22  [0.5147135643391956, 0.5518021939752743]  0.533258
# 23  [0.5147135643391956, 0.5518021939752743]  0.533258
# 24  [0.5147135643391956, 0.5518021939752743]  0.533258
# 25  [0.5147135643391956, 0.5518021939752743]  0.533258
# 26  [0.5147135643391956, 0.5518021939752743]  0.533258
# 27  [0.5147135643391956, 0.5518021939752743]  0.533258
# 28    [0.51453943931743, 0.5518021939752743]  0.533171
# 29    [0.51453943931743, 0.5518021939752743]  0.533171
# 30    [0.51453943931743, 0.5518021939752743]  0.533171
#
#                                         feature_names  ci_bound   std_dev  \
# 1                             (fulladdress_count_30,)  0.010863  0.002525
# 2            (fulladdress_count_30, ssn_dob_count_30)  0.051695  0.012015
# 3   (fulladdress_count_30, fulladdress_unique_coun...  0.063682  0.014801
# 4   (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 5   (address_count_30, fulladdress_count_30, fulla...  0.073796  0.017151
# 6   (address_count_30, fulladdress_count_30, fulla...  0.073796  0.017151
# 7   (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 8   (address_count_30, fulladdress_count_30, fulla...  0.073796  0.017151
# 9   (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 10  (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 11  (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 12  (address_day_since, address_count_30, fulladdr...  0.071174  0.016542
# 13  (address_day_since, address_count_30, fulladdr...  0.076418  0.017761
# 14  (address_day_since, address_count_30, fulladdr...  0.073047  0.016977
# 15  (address_day_since, address_count_30, fulladdr...  0.080539  0.018718
# 16  (address_day_since, address_count_30, fulladdr...   0.07979  0.018544
# 17  (address_day_since, address_count_30, fulladdr...   0.07979  0.018544
# 18  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 19  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 20  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 21  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 22  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 23  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 24  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 25  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 26  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 27  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 28  (address_day_since, fulladdress_day_since, add...  0.080164  0.018631
# 29  (address_day_since, fulladdress_day_since, add...  0.080164  0.018631
# 30  (address_day_since, fulladdress_day_since, add...  0.080164  0.018631
#
#      std_err
# 1   0.002525
# 2   0.012015
# 3   0.014801
# 4   0.017238
# 5   0.017151
# 6   0.017151
# 7   0.017238
# 8   0.017151
# 9   0.017238
# 10  0.017238
# 11  0.017238
# 12  0.016542
# 13  0.017761
# 14  0.016977
# 15  0.018718
# 16  0.018544
# 17  0.018544
# 18  0.018544
# 19  0.018544
# 20  0.018544
# 21  0.018544
# 22  0.018544
# 23  0.018544
# 24  0.018544
# 25  0.018544
# 26  0.018544
# 27  0.018544
# 28  0.018631
# 29  0.018631
# 30  0.018631

# %%
vars_FS = pd.DataFrame.from_dict(sfs.get_metric_dict()).T
vars_FS
# Out:
#                                           feature_idx  \
# 1                                                (3,)
# 2                                             (3, 95)
# 3                                         (3, 12, 95)
# 4                                      (2, 3, 12, 95)
# 5                                  (2, 3, 12, 20, 95)
# 6                              (2, 3, 12, 20, 22, 95)
# 7                          (2, 3, 12, 20, 22, 95, 97)
# 8                      (2, 3, 12, 20, 22, 32, 95, 97)
# 9                  (2, 3, 12, 20, 22, 24, 32, 95, 97)
# 10             (2, 3, 12, 20, 22, 24, 32, 35, 95, 97)
# 11         (2, 3, 12, 20, 22, 24, 32, 35, 36, 95, 97)
# 12      (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 95, 97)
# 13  (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 92, 95, 97)
# 14  (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 92, 94, ...
# 15  (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 47, 92, ...
# 16  (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 47, 92, ...
# 17  (0, 2, 3, 4, 12, 20, 22, 24, 32, 35, 36, 47, 9...
# 18  (0, 1, 2, 3, 4, 12, 20, 22, 24, 32, 35, 36, 47...
# 19  (0, 1, 2, 3, 4, 5, 12, 20, 22, 24, 32, 35, 36,...
# 20  (0, 1, 2, 3, 4, 5, 8, 12, 20, 22, 24, 32, 35, ...
# 21  (0, 1, 2, 3, 4, 5, 8, 9, 12, 20, 22, 24, 32, 3...
# 22  (0, 1, 2, 3, 4, 5, 8, 9, 12, 20, 22, 24, 32, 3...
# 23  (0, 1, 2, 3, 4, 5, 8, 9, 10, 12, 20, 22, 24, 3...
# 24  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 25  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 26  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 27  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 28  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 29  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
# 30  (0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 20, 22, 2...
#
#                                    cv_scores avg_score  \
# 1    [0.351732543966568, 0.3567821695977712]  0.354257
# 2    [0.5035695629461954, 0.527598815949852]  0.515584
# 3   [0.5072261884032736, 0.5368274421034303]  0.522027
# 4   [0.5075744384468048, 0.5420511927563991]  0.524813
# 5   [0.5077485634685704, 0.5420511927563991]    0.5249
# 6   [0.5077485634685704, 0.5420511927563991]    0.5249
# 7   [0.5075744384468048, 0.5420511927563991]  0.524813
# 8   [0.5077485634685704, 0.5420511927563991]    0.5249
# 9   [0.5075744384468048, 0.5420511927563991]  0.524813
# 10  [0.5075744384468048, 0.5420511927563991]  0.524813
# 11  [0.5075744384468048, 0.5420511927563991]  0.524813
# 12  [0.5077485634685704, 0.5408323176040397]   0.52429
# 13  [0.5121016890127111, 0.5476231934528992]  0.529862
# 14  [0.5143653142956642, 0.5483196935399617]  0.531343
# 15  [0.5143653142956642, 0.5518021939752743]  0.533084
# 16  [0.5147135643391956, 0.5518021939752743]  0.533258
# 17  [0.5147135643391956, 0.5518021939752743]  0.533258
# 18  [0.5147135643391956, 0.5518021939752743]  0.533258
# 19  [0.5147135643391956, 0.5518021939752743]  0.533258
# 20  [0.5147135643391956, 0.5518021939752743]  0.533258
# 21  [0.5147135643391956, 0.5518021939752743]  0.533258
# 22  [0.5147135643391956, 0.5518021939752743]  0.533258
# 23  [0.5147135643391956, 0.5518021939752743]  0.533258
# 24  [0.5147135643391956, 0.5518021939752743]  0.533258
# 25  [0.5147135643391956, 0.5518021939752743]  0.533258
# 26  [0.5147135643391956, 0.5518021939752743]  0.533258
# 27  [0.5147135643391956, 0.5518021939752743]  0.533258
# 28    [0.51453943931743, 0.5518021939752743]  0.533171
# 29    [0.51453943931743, 0.5518021939752743]  0.533171
# 30    [0.51453943931743, 0.5518021939752743]  0.533171
#
#                                         feature_names  ci_bound   std_dev  \
# 1                             (fulladdress_count_30,)  0.010863  0.002525
# 2            (fulladdress_count_30, ssn_dob_count_30)  0.051695  0.012015
# 3   (fulladdress_count_30, fulladdress_unique_coun...  0.063682  0.014801
# 4   (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 5   (address_count_30, fulladdress_count_30, fulla...  0.073796  0.017151
# 6   (address_count_30, fulladdress_count_30, fulla...  0.073796  0.017151
# 7   (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 8   (address_count_30, fulladdress_count_30, fulla...  0.073796  0.017151
# 9   (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 10  (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 11  (address_count_30, fulladdress_count_30, fulla...  0.074171  0.017238
# 12  (address_day_since, address_count_30, fulladdr...  0.071174  0.016542
# 13  (address_day_since, address_count_30, fulladdr...  0.076418  0.017761
# 14  (address_day_since, address_count_30, fulladdr...  0.073047  0.016977
# 15  (address_day_since, address_count_30, fulladdr...  0.080539  0.018718
# 16  (address_day_since, address_count_30, fulladdr...   0.07979  0.018544
# 17  (address_day_since, address_count_30, fulladdr...   0.07979  0.018544
# 18  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 19  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 20  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 21  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 22  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 23  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 24  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 25  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 26  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 27  (address_day_since, fulladdress_day_since, add...   0.07979  0.018544
# 28  (address_day_since, fulladdress_day_since, add...  0.080164  0.018631
# 29  (address_day_since, fulladdress_day_since, add...  0.080164  0.018631
# 30  (address_day_since, fulladdress_day_since, add...  0.080164  0.018631
#
#      std_err
# 1   0.002525
# 2   0.012015
# 3   0.014801
# 4   0.017238
# 5   0.017151
# 6   0.017151
# 7   0.017238
# 8   0.017151
# 9   0.017238
# 10  0.017238
# 11  0.017238
# 12  0.016542
# 13  0.017761
# 14  0.016977
# 15  0.018718
# 16  0.018544
# 17  0.018544
# 18  0.018544
# 19  0.018544
# 20  0.018544
# 21  0.018544
# 22  0.018544
# 23  0.018544
# 24  0.018544
# 25  0.018544
# 26  0.018544
# 27  0.018544
# 28  0.018631
# 29  0.018631
# 30  0.018631

# %%
vars_final = list(vars_FS.loc[num_wrapper, 'feature_names'])
vars_final
# Out:
# ['address_day_since',
#  'fulladdress_day_since',
#  'address_count_30',
#  'fulladdress_count_30',
#  'address_count_14',
#  'fulladdress_count_14',
#  'address_count_7',
#  'fulladdress_count_7',
#  'address_count_0_by_30',
#  'fulladdress_count_0_by_30',
#  'fulladdress_unique_count_for_dob_homephone_60',
#  'fulladdress_unique_count_for_ssn_name_dob_60',
#  'fulladdress_unique_count_for_name_dob_60',
#  'fulladdress_unique_count_for_fulladdress_dob_60',
#  'fulladdress_unique_count_for_dob_homephone_30',
#  'address_count_0_by_14',
#  'fulladdress_unique_count_for_ssn_name_dob_30',
#  'fulladdress_count_0_by_14',
#  'fulladdress_unique_count_for_name_dob_30',
#  'fulladdress_unique_count_for_fulladdress_dob_30',
#  'fulladdress_count_3',
#  'address_count_3',
#  'fulladdress_unique_count_for_ssn_name_dob_14',
#  'fulladdress_unique_count_for_name_dob_7',
#  'fulladdress_homephone_day_since',
#  'fulladdress_homephone_count_30',
#  'ssn_dob_day_since',
#  'ssn_dob_count_30',
#  'name_dob_day_since',
#  'name_dob_count_30']

# %%
vars_FS.to_csv('VarsFS.csv', index=False)

# %%
sfs.subsets_
# Out:
# {1: {'feature_idx': (3,),
#   'cv_scores': array([0.35173254, 0.35678217]),
#   'avg_score': 0.35425735678216963,
#   'feature_names': ('fulladdress_count_30',)},
#  2: {'feature_idx': (3, 95),
#   'cv_scores': array([0.50356956, 0.52759882]),
#   'avg_score': 0.5155841894480238,
#   'feature_names': ('fulladdress_count_30', 'ssn_dob_count_30')},
#  3: {'feature_idx': (3, 12, 95),
#   'cv_scores': array([0.50722619, 0.53682744]),
#   'avg_score': 0.5220268152533519,
#   'feature_names': ('fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'ssn_dob_count_30')},
#  4: {'feature_idx': (2, 3, 12, 95),
#   'cv_scores': array([0.50757444, 0.54205119]),
#   'avg_score': 0.524812815601602,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'ssn_dob_count_30')},
#  5: {'feature_idx': (2, 3, 12, 20, 95),
#   'cv_scores': array([0.50774856, 0.54205119]),
#   'avg_score': 0.5248998781124847,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'ssn_dob_count_30')},
#  6: {'feature_idx': (2, 3, 12, 20, 22, 95),
#   'cv_scores': array([0.50774856, 0.54205119]),
#   'avg_score': 0.5248998781124847,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'ssn_dob_count_30')},
#  7: {'feature_idx': (2, 3, 12, 20, 22, 95, 97),
#   'cv_scores': array([0.50757444, 0.54205119]),
#   'avg_score': 0.524812815601602,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  8: {'feature_idx': (2, 3, 12, 20, 22, 32, 95, 97),
#   'cv_scores': array([0.50774856, 0.54205119]),
#   'avg_score': 0.5248998781124847,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  9: {'feature_idx': (2, 3, 12, 20, 22, 24, 32, 95, 97),
#   'cv_scores': array([0.50757444, 0.54205119]),
#   'avg_score': 0.524812815601602,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  10: {'feature_idx': (2, 3, 12, 20, 22, 24, 32, 35, 95, 97),
#   'cv_scores': array([0.50757444, 0.54205119]),
#   'avg_score': 0.524812815601602,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  11: {'feature_idx': (2, 3, 12, 20, 22, 24, 32, 35, 36, 95, 97),
#   'cv_scores': array([0.50757444, 0.54205119]),
#   'avg_score': 0.524812815601602,
#   'feature_names': ('address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  12: {'feature_idx': (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 95, 97),
#   'cv_scores': array([0.50774856, 0.54083232]),
#   'avg_score': 0.5242904405363051,
#   'feature_names': ('address_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  13: {'feature_idx': (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 92, 95, 97),
#   'cv_scores': array([0.51210169, 0.54762319]),
#   'avg_score': 0.5298624412328052,
#   'feature_names': ('address_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  14: {'feature_idx': (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 92, 94, 95, 97),
#   'cv_scores': array([0.51436531, 0.54831969]),
#   'avg_score': 0.531342503917813,
#   'feature_names': ('address_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  15: {'feature_idx': (0, 2, 3, 12, 20, 22, 24, 32, 35, 36, 47, 92, 94, 95, 97),
#   'cv_scores': array([0.51436531, 0.55180219]),
#   'avg_score': 0.5330837541354693,
#   'feature_names': ('address_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_count_30')},
#  16: {'feature_idx': (0,
#    2,
#    3,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  17: {'feature_idx': (0,
#    2,
#    3,
#    4,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  18: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  19: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  20: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  21: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  22: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    37,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  23: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    10,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    37,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'address_count_0_by_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  24: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    10,
#    11,
#    12,
#    20,
#    22,
#    24,
#    32,
#    35,
#    36,
#    37,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'address_count_0_by_30',
#    'fulladdress_count_0_by_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  25: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    10,
#    11,
#    12,
#    20,
#    22,
#    23,
#    24,
#    32,
#    35,
#    36,
#    37,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'address_count_0_by_30',
#    'fulladdress_count_0_by_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_fulladdress_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  26: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    10,
#    11,
#    12,
#    20,
#    22,
#    23,
#    24,
#    32,
#    35,
#    36,
#    37,
#    38,
#    47,
#    92,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'address_count_0_by_30',
#    'fulladdress_count_0_by_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_fulladdress_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'address_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  27: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    10,
#    11,
#    12,
#    20,
#    22,
#    23,
#    24,
#    32,
#    35,
#    36,
#    37,
#    38,
#    47,
#    92,
#    93,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51471356, 0.55180219]),
#   'avg_score': 0.5332578791572349,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'address_count_0_by_30',
#    'fulladdress_count_0_by_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_fulladdress_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'address_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_homephone_day_since',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  28: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    10,
#    11,
#    12,
#    20,
#    22,
#    23,
#    24,
#    32,
#    35,
#    36,
#    37,
#    38,
#    47,
#    61,
#    92,
#    93,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51453944, 0.55180219]),
#   'avg_score': 0.5331708166463521,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'address_count_0_by_30',
#    'fulladdress_count_0_by_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_fulladdress_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'address_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_unique_count_for_name_dob_7',
#    'fulladdress_homephone_day_since',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  29: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    10,
#    11,
#    12,
#    20,
#    22,
#    23,
#    24,
#    31,
#    32,
#    35,
#    36,
#    37,
#    38,
#    47,
#    61,
#    92,
#    93,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51453944, 0.55180219]),
#   'avg_score': 0.5331708166463521,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'address_count_0_by_30',
#    'fulladdress_count_0_by_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_fulladdress_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'address_count_0_by_14',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'address_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_unique_count_for_name_dob_7',
#    'fulladdress_homephone_day_since',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')},
#  30: {'feature_idx': (0,
#    1,
#    2,
#    3,
#    4,
#    5,
#    8,
#    9,
#    10,
#    11,
#    12,
#    20,
#    22,
#    23,
#    24,
#    31,
#    32,
#    33,
#    35,
#    36,
#    37,
#    38,
#    47,
#    61,
#    92,
#    93,
#    94,
#    95,
#    96,
#    97),
#   'cv_scores': array([0.51453944, 0.55180219]),
#   'avg_score': 0.5331708166463521,
#   'feature_names': ('address_day_since',
#    'fulladdress_day_since',
#    'address_count_30',
#    'fulladdress_count_30',
#    'address_count_14',
#    'fulladdress_count_14',
#    'address_count_7',
#    'fulladdress_count_7',
#    'address_count_0_by_30',
#    'fulladdress_count_0_by_30',
#    'fulladdress_unique_count_for_dob_homephone_60',
#    'fulladdress_unique_count_for_ssn_name_dob_60',
#    'fulladdress_unique_count_for_name_dob_60',
#    'fulladdress_unique_count_for_fulladdress_dob_60',
#    'fulladdress_unique_count_for_dob_homephone_30',
#    'address_count_0_by_14',
#    'fulladdress_unique_count_for_ssn_name_dob_30',
#    'fulladdress_count_0_by_14',
#    'fulladdress_unique_count_for_name_dob_30',
#    'fulladdress_unique_count_for_fulladdress_dob_30',
#    'fulladdress_count_3',
#    'address_count_3',
#    'fulladdress_unique_count_for_ssn_name_dob_14',
#    'fulladdress_unique_count_for_name_dob_7',
#    'fulladdress_homephone_day_since',
#    'fulladdress_homephone_count_30',
#    'ssn_dob_day_since',
#    'ssn_dob_count_30',
#    'name_dob_day_since',
#    'name_dob_count_30')}}

# %%
vars_final.append('index_name')
vars_final.append('y_name')
vars_final
# Out:
# ['address_day_since',
#  'fulladdress_day_since',
#  'address_count_30',
#  'fulladdress_count_30',
#  'address_count_14',
#  'fulladdress_count_14',
#  'address_count_7',
#  'fulladdress_count_7',
#  'address_count_0_by_30',
#  'fulladdress_count_0_by_30',
#  'fulladdress_unique_count_for_dob_homephone_60',
#  'fulladdress_unique_count_for_ssn_name_dob_60',
#  'fulladdress_unique_count_for_name_dob_60',
#  'fulladdress_unique_count_for_fulladdress_dob_60',
#  'fulladdress_unique_count_for_dob_homephone_30',
#  'address_count_0_by_14',
#  'fulladdress_unique_count_for_ssn_name_dob_30',
#  'fulladdress_count_0_by_14',
#  'fulladdress_unique_count_for_name_dob_30',
#  'fulladdress_unique_count_for_fulladdress_dob_30',
#  'fulladdress_count_3',
#  'address_count_3',
#  'fulladdress_unique_count_for_ssn_name_dob_14',
#  'fulladdress_unique_count_for_name_dob_7',
#  'fulladdress_homephone_day_since',
#  'fulladdress_homephone_count_30',
#  'ssn_dob_day_since',
#  'ssn_dob_count_30',
#  'name_dob_day_since',
#  'name_dob_count_30',
#  'index_name',
#  'y_name']

# %%
X_final = df_keep.filter(vars_final, axis=1)
X_final.shape
# Out:
# (794997, 30)

# %%
X_final.to_csv('vars_final.csv', index=False)
